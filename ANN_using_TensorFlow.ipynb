# %% [markdown]
# <a href="https://colab.research.google.com/github/EricSiq/DeepLearning/blob/main/ANN_using_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

# Step 1: Load and preprocess the Iris dataset
def load_and_preprocess_iris_data():
    """
    Loads the Iris dataset, preprocesses features (normalization),
    and one-hot encodes target labels.
    Includes error handling for data loading.
    """
    try:
        print("Loading and preprocessing the Iris dataset...")
        iris = load_iris()
        X = iris.data
        y = iris.target.reshape(-1, 1) # Reshape targets for OneHotEncoder

        # Normalize features to a 0-1 range
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X)
        print(f"Features scaled. Original min/max: {np.min(X):.2f}/{np.max(X):.2f}, Scaled min/max: {np.min(X_scaled):.2f}/{np.max(X_scaled):.2f}")

        # One-hot encode target labels
        encoder = OneHotEncoder(sparse_output=False)
        y_one_hot = encoder.fit_transform(y)
        print(f"Target labels one-hot encoded. Example: {y[0]} -> {y_one_hot[0]}")

        # Split data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(
            X_scaled, y_one_hot, test_size=0.2, random_state=42, stratify=y # stratify to maintain class distribution
        )
        print(f"Data split into training ({X_train.shape[0]} samples) and testing ({X_test.shape[0]} samples) sets.")
        return X_train, X_test, y_train, y_test, iris.target_names
    except Exception as e:
        raise RuntimeError(f"Error during data loading or preprocessing: {e}")

# Step 2: Define the ANN model architecture using TensorFlow/Keras
def define_ann_model(input_shape, num_classes):
    """
    Defines a Sequential Keras model for multi-class classification.
    Includes error handling for input parameters.
    """
    if not isinstance(input_shape, tuple) or len(input_shape) != 1 or not isinstance(input_shape[0], int) or input_shape[0] <= 0:
        raise ValueError("input_shape must be a tuple representing a positive integer (e.g., (4,)).")
    if not isinstance(num_classes, int) or num_classes <= 0:
        raise ValueError("num_classes must be a positive integer.")

    print("\nDefining the ANN model architecture...")
    model = tf.keras.Sequential([
        # Input layer: A Dense layer with 'input_shape' matching the number of features
        tf.keras.layers.Dense(units=10, activation='relu', input_shape=input_shape, name='input_hidden_layer'),
        # Hidden layer: Another Dense layer
        tf.keras.layers.Dense(units=8, activation='relu', name='hidden_layer'),
        # Output layer: Units equal to number of classes, softmax for multi-class probabilities
        tf.keras.layers.Dense(units=num_classes, activation='softmax', name='output_layer')
    ])
    print("Model architecture defined:")
    model.summary() # Print a summary of the model's layers
    return model

# Step 3: Compile the model
def compile_model(model, learning_rate=0.01):
    """
    Compiles the Keras model with an optimizer, loss function, and metrics.
    Includes error handling for learning rate.
    """
    if not isinstance(learning_rate, (int, float)) or not (0 < learning_rate <= 1):
        raise ValueError("Learning rate must be a number between 0 and 1.")

    print("\nCompiling the model...")
    # Using Adam optimizer, categorical_crossentropy for one-hot encoded labels, and accuracy metric
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print("Model compiled successfully.")

# Step 4: Train the model
def train_model(model, X_train, y_train, epochs=100, batch_size=32):
    """
    Trains the compiled Keras model using the training data.
    Includes error handling for epochs and batch_size.
    """
    if not isinstance(epochs, int) or epochs <= 0:
        raise ValueError("Epochs must be a positive integer.")
    if not isinstance(batch_size, int) or batch_size <= 0:
        raise ValueError("Batch size must be a positive integer.")
    if not isinstance(X_train, np.ndarray) or not isinstance(y_train, np.ndarray):
        raise TypeError("Training inputs and targets must be numpy arrays.")
    if X_train.shape[0] != y_train.shape[0]:
        raise ValueError("Number of samples in training inputs and targets must match.")

    print(f"\nTraining the model for {epochs} epochs with a batch size of {batch_size}...")
    history = model.fit(X_train, y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        verbose=1) # verbose=1 shows progress bar
    print("Model training complete.")
    return history

# Step 5: Evaluate the model
def evaluate_model(model, X_test, y_test):
    """
    Evaluates the trained Keras model on the test data.
    Includes error handling for test data.
    """
    if not isinstance(X_test, np.ndarray) or not isinstance(y_test, np.ndarray):
        raise TypeError("Test inputs and targets must be numpy arrays.")
    if X_test.shape[0] != y_test.shape[0]:
        raise ValueError("Number of samples in test inputs and targets must match.")

    print("\nEvaluating the model on the test set...")
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss: {loss:.4f}")
    print(f"Test Accuracy: {accuracy*100:.2f}%")
    return loss, accuracy

# Step 6: Make predictions and interpret results
def make_predictions(model, X_new, target_names):
    """
    Makes predictions on new data and converts probabilities to class labels.
    Includes error handling for input data and target names.
    """
    if not isinstance(X_new, np.ndarray):
        raise TypeError("New input data must be a numpy array.")
    if X_new.shape[1] != model.input_shape[1]:
        raise ValueError(f"New input data shape mismatch. Expected {model.input_shape[1]} features, got {X_new.shape[1]}.")
    if not isinstance(target_names, np.ndarray) or target_names.dtype.kind not in 'US':
        raise TypeError("target_names must be a numpy array of strings.")

    print("\nMaking predictions on new data...")
    # Get probability predictions from the model
    probabilities = model.predict(X_new, verbose=0)
    # Get the index of the highest probability (predicted class)
    predicted_classes_indices = np.argmax(probabilities, axis=1)

    # Map indices back to original class names
    predicted_class_names = [target_names[idx] for idx in predicted_classes_indices]

    print("Predictions:")
    for i, (input_sample, pred_prob, pred_class_name) in enumerate(zip(X_new, probabilities, predicted_class_names)):
        print(f"Sample {i+1}: Input features: {input_sample}, Predicted Probabilities: {np.round(pred_prob, 3)}, Predicted Class: {pred_class_name}")
    return predicted_classes_indices, predicted_class_names

# Main execution block
if __name__ == '__main__':
    try:
        # Load and preprocess data
        X_train, X_test, y_train, y_test, target_names = load_and_preprocess_iris_data()

        # Define model
        input_shape = (X_train.shape[1],) # (4,) for Iris features
        num_classes = y_train.shape[1]    # 3 for Iris species
        model = define_ann_model(input_shape, num_classes)

        # Compile model
        compile_model(model, learning_rate=0.001) # Using a slightly smaller learning rate for TensorFlow

        # Train model
        train_model(model, X_train, y_train, epochs=200, batch_size=16) # More epochs and smaller batch size for better convergence

        # Evaluate model
        evaluate_model(model, X_test, y_test)

        # Example new data for prediction (scaled to match training data)
        # Let's pick a few samples from the original X to demonstrate, then scale them
        sample_indices_for_prediction = [0, 50, 100, 75] # Original indices for Setosa, Versicolor, Virginica, and another Versicolor

        # Re-initialize scaler and fit on original X to ensure consistent scaling for new data
        full_data_scaler = MinMaxScaler()
        full_data_scaler.fit(load_iris().data) # Fit on the entire original dataset

        X_new_raw = load_iris().data[sample_indices_for_prediction]
        X_new_scaled = full_data_scaler.transform(X_new_raw)

        # Get actual labels for these samples for comparison
        y_new_actual_indices = load_iris().target[sample_indices_for_prediction]
        y_new_actual_names = [target_names[idx] for idx in y_new_actual_indices]
        print(f"\nActual classes for new samples: {y_new_actual_names}")

        # Make predictions
        predicted_classes_indices, predicted_class_names = make_predictions(model, X_new_scaled, target_names)

    except RuntimeError as e:
        print(f"Application Error: {e}")
    except ValueError as e:
        print(f"Configuration Error: {e}")
    except TypeError as e:
        print(f"Type Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Loading and preprocessing the Iris dataset...
# Features scaled. Original min/max: 0.10/7.90, Scaled min/max: 0.00/1.00
# Target labels one-hot encoded. Example: [0] -> [1. 0. 0.]
# Data split into training (120 samples) and testing (30 samples) sets.
#
# Defining the ANN model architecture...
# Model architecture defined:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_hidden_layer (Dense)      │ (None, 10)             │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden_layer (Dense)            │ (None, 8)              │            88 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 165 (660.00 B)
#  Trainable params: 165 (660.00 B)
#  Non-trainable params: 0 (0.00 B)
# Compiling the model...
# Model compiled successfully.
#
# Training the model for 200 epochs with a batch size of 16...
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.3553 - loss: 1.0801
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3872 - loss: 1.0559
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3379 - loss: 1.0505
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3663 - loss: 1.0282
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3195 - loss: 1.0320
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3563 - loss: 1.0082
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3272 - loss: 1.0060
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3723 - loss: 0.9738
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3506 - loss: 0.9777
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3198 - loss: 0.9814
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5021 - loss: 0.9323
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5878 - loss: 0.9512
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7401 - loss: 0.9366
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7930 - loss: 0.9028
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8011 - loss: 0.9008
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7398 - loss: 0.9001
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7978 - loss: 0.8504
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 0.8527
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8405 - loss: 0.8606
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8815 - loss: 0.8279
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8610 - loss: 0.8355
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8850 - loss: 0.8101
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8913 - loss: 0.7691
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8831 - loss: 0.7850
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9097 - loss: 0.7701
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9138 - loss: 0.7289
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9751 - loss: 0.7666
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9414 - loss: 0.7383
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8954 - loss: 0.7527
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8962 - loss: 0.7843
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9186 - loss: 0.7477
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9393 - loss: 0.7001
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9482 - loss: 0.6879
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9431 - loss: 0.7111
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9471 - loss: 0.6348
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9501 - loss: 0.7105
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8984 - loss: 0.6662
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9215 - loss: 0.6853
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9356 - loss: 0.6390
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9507 - loss: 0.6428
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9144 - loss: 0.6313
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9143 - loss: 0.6259
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9182 - loss: 0.6098
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9371 - loss: 0.6203
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9094 - loss: 0.6157
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9165 - loss: 0.5611
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9403 - loss: 0.5917
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9150 - loss: 0.6242
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9163 - loss: 0.6217
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9609 - loss: 0.5459
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9213 - loss: 0.5814
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9545 - loss: 0.5381
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9100 - loss: 0.5919
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9470 - loss: 0.5569
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9207 - loss: 0.4989
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9325 - loss: 0.5376
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9534 - loss: 0.5000
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9372 - loss: 0.5035
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9575 - loss: 0.5426
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9522 - loss: 0.4888
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9197 - loss: 0.4715
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9256 - loss: 0.4982
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9632 - loss: 0.5102
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9684 - loss: 0.4600
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9665 - loss: 0.4744
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9515 - loss: 0.4636
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9670 - loss: 0.4741
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9548 - loss: 0.4322
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9669 - loss: 0.4207
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9568 - loss: 0.4051
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9459 - loss: 0.4150
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9525 - loss: 0.4383
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9430 - loss: 0.3900
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9629 - loss: 0.3647
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9713 - loss: 0.3703
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9541 - loss: 0.3763
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9657 - loss: 0.3701
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9641 - loss: 0.3534
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9519 - loss: 0.3691
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9549 - loss: 0.3754
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9449 - loss: 0.3749
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9720 - loss: 0.3295
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9598 - loss: 0.3308
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9776 - loss: 0.3082
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9695 - loss: 0.3451
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9651 - loss: 0.3576
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9703 - loss: 0.3290
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9669 - loss: 0.3159
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9584 - loss: 0.3048
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9648 - loss: 0.2891
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9820 - loss: 0.2844
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9600 - loss: 0.3077
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9334 - loss: 0.2838
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9820 - loss: 0.2658
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9705 - loss: 0.2508
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.2636
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9611 - loss: 0.2789
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9461 - loss: 0.2652
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9648 - loss: 0.2449
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9596 - loss: 0.2468
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9658 - loss: 0.2348
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9605 - loss: 0.2268
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9362 - loss: 0.2542
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9708 - loss: 0.2192
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9835 - loss: 0.2019
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9623 - loss: 0.2428
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9492 - loss: 0.2472
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9712 - loss: 0.2258
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9563 - loss: 0.1948
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9545 - loss: 0.2216
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9493 - loss: 0.2274
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9588 - loss: 0.1981
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9536 - loss: 0.2164
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9467 - loss: 0.2145
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9835 - loss: 0.1691
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9374 - loss: 0.2011
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9552 - loss: 0.1989
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9256 - loss: 0.2283
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9463 - loss: 0.2006
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9496 - loss: 0.1734
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9285 - loss: 0.1866
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9614 - loss: 0.1695
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9590 - loss: 0.1872
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9620 - loss: 0.1605
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9614 - loss: 0.1719
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9599 - loss: 0.1627
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9524 - loss: 0.1633
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9395 - loss: 0.1746
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9720 - loss: 0.1389
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9681 - loss: 0.1637
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9842 - loss: 0.1355
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9469 - loss: 0.1675
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9557 - loss: 0.1466
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9533 - loss: 0.1392
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1339
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9740 - loss: 0.1406
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9645 - loss: 0.1444
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9467 - loss: 0.1614
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9597 - loss: 0.1373
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9624 - loss: 0.1334
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9501 - loss: 0.1411
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9215 - loss: 0.1624
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9452 - loss: 0.1346
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.1375
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9339 - loss: 0.1554
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9558 - loss: 0.1491
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9700 - loss: 0.1281
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9585 - loss: 0.1360
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9374 - loss: 0.1396
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9624 - loss: 0.1166
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9582 - loss: 0.1218
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9838 - loss: 0.1040
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9777 - loss: 0.0983
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9764 - loss: 0.1122
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9743 - loss: 0.1054
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9584 - loss: 0.1272
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9326 - loss: 0.1470
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9736 - loss: 0.1031
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9706 - loss: 0.0957
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9852 - loss: 0.1044
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9592 - loss: 0.1254
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0832
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9732 - loss: 0.1028
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9575 - loss: 0.1036
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - loss: 0.1092
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9679 - loss: 0.1044
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.0986
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9636 - loss: 0.1087
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9766 - loss: 0.0896
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 0.0815
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9706 - loss: 0.1147
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9659 - loss: 0.1084
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9703 - loss: 0.1033
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9445 - loss: 0.1152
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9687 - loss: 0.0962
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9549 - loss: 0.1117
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9402 - loss: 0.1171
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9480 - loss: 0.1163
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9715 - loss: 0.0912
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9607 - loss: 0.1169
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9706 - loss: 0.0919
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9561 - loss: 0.1016
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9766 - loss: 0.0908
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9573 - loss: 0.0959
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9694 - loss: 0.0779
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9573 - loss: 0.1027
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9607 - loss: 0.0974
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9708 - loss: 0.0962
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9573 - loss: 0.0913
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9648 - loss: 0.0922
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9727 - loss: 0.0797
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9625 - loss: 0.0964
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9593 - loss: 0.0982
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9636 - loss: 0.0927
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9495 - loss: 0.1106
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9679 - loss: 0.0873
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9689 - loss: 0.0878
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9720 - loss: 0.0894
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9642 - loss: 0.0893
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.0781
# Model training complete.
#
# Evaluating the model on the test set...
# Test Loss: 0.1113
# Test Accuracy: 96.67%
#
# Actual classes for new samples: [np.str_('setosa'), np.str_('versicolor'), np.str_('virginica'), np.str_('versicolor')]
#
# Making predictions on new data...
# Predictions:
# Sample 1: Input features: [0.22222222 0.625      0.06779661 0.04166667], Predicted Probabilities: [0.999 0.001 0.   ], Predicted Class: setosa
# Sample 2: Input features: [0.75       0.5        0.62711864 0.54166667], Predicted Probabilities: [0.012 0.942 0.046], Predicted Class: versicolor
# Sample 3: Input features: [0.55555556 0.54166667 0.84745763 1.        ], Predicted Probabilities: [0.    0.004 0.995], Predicted Class: virginica
# Sample 4: Input features: [0.63888889 0.41666667 0.57627119 0.54166667], Predicted Probabilities: [0.013 0.941 0.046], Predicted Class: versicolor
